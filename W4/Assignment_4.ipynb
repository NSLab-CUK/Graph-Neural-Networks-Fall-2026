# %% [markdown]
# # Assignment 4
#
# ### Given the Citeseer graph in Pytorch Geometric in data/Citeseer
# Questions:
#
# 1) Show some graph statistics of the Citeseer graph (Number of nodes, number of edges,...)
# 2) Running the GraphSage, FastGCN, ASGCN, GraphSAINT, and ClusterGCN models on node classification
